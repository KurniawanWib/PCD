# %%
## Kurniawan Wibisono-202331187
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Membaca Data Gambar

# %%
## Kurniawan Wibisono-202331187
img = cv2.imread('pesawat.jpeg')

# %%
## Kurniawan Wibisono-202331187
img.shape
# Out:
# (202, 303, 3)

# %%
## Kurniawan Wibisono-202331187
[baris, kolom] = img.shape[:2]

# %% [markdown]
# ## Convert BGR To RGB

# %%
## Kurniawan Wibisono-202331187
rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ## Menampilkan Histogram

# %%
## Kurniawan Wibisono-202331187
fig, axs = plt.subplots(2,2,figsize=(15,5))

#cara1
axs[0,0].imshow(rgb)
axs[0,1].hist(rgb.ravel(),256,[0,256])

#cara2
hist = cv2.calcHist([rgb],[0],None,[256],[0,256])
axs[1,0].imshow(rgb)
axs[1,1].plot(hist)

#Menampilkan
plt.show()
# Out:
# C:\Users\kurni\AppData\Local\Temp\ipykernel_14204\892543289.py:5: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   axs[0,1].hist(rgb.ravel(),256,[0,256])

# %% [markdown]
# ## Operasi Piksel Untuk Meningkatkan Kecerahan

# %%
## Kurniawan Wibisono-202331187
beta = 40
citra_cerah = np.zeros((baris,kolom, 3))

for x in range(baris):
    for y in range(kolom):
        gyx =rgb[x,y] + beta
        citra_cerah[x,y] = gyx

citra_cerah = citra_cerah.astype(np.uint8)

fig,axs = plt.subplots(2,2,figsize=(15,5))
axs[0,0].imshow(rgb)
axs[0,1].hist(rgb.ravel(),256,[0,256])
axs[1,0].imshow(citra_cerah)
axs[1,1].hist(citra_cerah.ravel(),256,[0,256])

plt.show()
# Out:
# C:\Users\kurni\AppData\Local\Temp\ipykernel_14204\1474528474.py:13: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   axs[0,1].hist(rgb.ravel(),256,[0,256])
# C:\Users\kurni\AppData\Local\Temp\ipykernel_14204\1474528474.py:15: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   axs[1,1].hist(citra_cerah.ravel(),256,[0,256])

# %% [markdown]
# ## Meregangkan Kontras

# %%
## Kurniawan Wibisono-202331187
alpha = 1.2
citra_kontras = np.zeros((baris,kolom, 3))

for x in range(baris):
    for y in range(kolom):
        gyx =rgb[x,y] * alpha
        citra_kontras[x,y] = gyx

citra_kontras = citra_kontras.astype(np.uint8)

fig,axs = plt.subplots(2,2,figsize=(15,5))
axs[0,0].imshow(rgb)
axs[0,1].hist(rgb.ravel(),256,[0,256])
axs[1,0].imshow(citra_kontras)
axs[1,1].hist(citra_kontras.ravel(),256,[0,256])

plt.show()
# Out:
# C:\Users\kurni\AppData\Local\Temp\ipykernel_14204\2673095398.py:13: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   axs[0,1].hist(rgb.ravel(),256,[0,256])
# C:\Users\kurni\AppData\Local\Temp\ipykernel_14204\2673095398.py:15: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   axs[1,1].hist(citra_kontras.ravel(),256,[0,256])

# %% [markdown]
# ## Operasi Gabungan Antara Kontras dan Meregangkan Kontras

# %%
## Kurniawan Wibisono-202331187
beta =10
alpha = 1.2
citra_hasil = np.zeros((baris,kolom, 3))

for x in range(baris):
    for y in range(kolom):
        gyx =alpha * rgb[x,y] + beta 
        citra_hasil[x,y] = gyx

citra_hasil = citra_hasil.astype(np.uint8)

fig,axs = plt.subplots(2,2,figsize=(15,5))
axs[0,0].imshow(rgb)
axs[0,1].hist(rgb.ravel(),256,[0,256])
axs[1,0].imshow(citra_hasil)
axs[1,1].hist(citra_hasil.ravel(),256,[0,256])

plt.show()
# Out:
# C:\Users\kurni\AppData\Local\Temp\ipykernel_14204\2624584103.py:14: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   axs[0,1].hist(rgb.ravel(),256,[0,256])
# C:\Users\kurni\AppData\Local\Temp\ipykernel_14204\2624584103.py:16: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   axs[1,1].hist(citra_hasil.ravel(),256,[0,256])

# %% [markdown]
# ## Membalikan Citra

# %%
## Kurniawan Wibisono-202331187
citra_negatif = np.zeros((baris,kolom, 3))

for x in range(baris):
    for y in range(kolom):
        gyx = 255 - rgb[x,y] 
        citra_negatif[x,y] = gyx

citra_negatif = citra_negatif.astype(np.uint8)

fig,axs = plt.subplots(2,2,figsize=(15,5))
axs[0,0].imshow(rgb)
axs[0,1].hist(rgb.ravel(),256,[0,256])
axs[1,0].imshow(citra_negatif)
axs[1,1].hist(citra_negatif.ravel(),256,[0,256])

plt.show()
# Out:
# C:\Users\kurni\AppData\Local\Temp\ipykernel_14204\2715564760.py:12: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   axs[0,1].hist(rgb.ravel(),256,[0,256])
# C:\Users\kurni\AppData\Local\Temp\ipykernel_14204\2715564760.py:14: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   axs[1,1].hist(citra_negatif.ravel(),256,[0,256])
